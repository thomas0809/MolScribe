# %% [markdown]
# # Indigo and ChemDraw

# %%
import pandas as pd

data = pd.read_csv('../data/molbank/indigo-data/valid.csv')
data_out = pd.read_csv('../data/molbank/chemdraw-data/valid.csv')
pred_in = pd.read_csv('../output/indigo/swin_base_20_dynamic_aug/prediction_valid_indigo.csv')
pred_out = pd.read_csv('../output/indigo/swin_base_20_dynamic_aug/prediction_valid_chemdraw.csv')

# %%
import numpy as np

print(np.mean(data['SMILES'].values == pred_in['SMILES'].values))
print(np.mean(data['SMILES'].values == pred_out['SMILES'].values))

print(np.mean(data['InChI'].values == pred_in['SMILES_InChI'].values))
print(np.mean(data['InChI'].values == pred_out['SMILES_InChI'].values))
# Out:
# 0.7399127589967285
# 0.5406215921483097
# 0.8209514721919302
# 0.7376635768811342

# %%
exact_match_in = (data['InChI'].values == pred_in['SMILES_InChI'].values)
exact_match_out = (data['InChI'].values == pred_out['SMILES_InChI'].values)

stats = np.zeros((2,2))

for i, smiles in enumerate(data['SMILES'].values):
    stats[int(exact_match_in[i]), int(exact_match_out[i])] += 1

print(stats)
# Out:
# [[ 2219.   408.]
#  [ 1630. 10415.]]

# %%
import cv2
import matplotlib.pyplot as plt
import rdkit.Chem as Chem
from rdkit.Chem import Draw
from IPython.display import SVG

BASE = '../'

cnt = 0 
for i, row in data.iterrows():
    if exact_match_in[i] and not exact_match_out[i]:
        cnt += 1
        print(row['SMILES'])
        pred_smiles_in = pred_in.loc[i,'SMILES']
        pred_smiles_out = pred_out.loc[i,'SMILES']
        print('pred in:', pred_in.loc[i,'SMILES_InChI'])
        print('pred out:', pred_out.loc[i,'SMILES_InChI'])
        image_in = cv2.imread(BASE + row['file_path'])
        image_out = cv2.imread(BASE + data_out.loc[i,'file_path'])
        plt.figure(figsize=(10,5))
        plt.subplot(1,2,1)
        plt.axis('off')
        plt.imshow(image_in)
        plt.subplot(1,2,2)
        plt.axis('off')
        plt.imshow(image_out)
        plt.show()
        mol_in = Chem.MolFromSmiles(pred_smiles_in)
        mol_out = Chem.MolFromSmiles(pred_smiles_out)
        img = Draw.MolsToGridImage([mol_in,mol_out], subImgSize=(300,300), molsPerRow=2, useSVG=True)
        display(img)
    if cnt == 10:
        break
# Out:
# CON=C(C(=O)NC1C(=O)N2C(C(=O)[O-])=CCSC12)C1=CSC(N)=N1
# pred in: InChI=1S/C13H13N5O5S2/c1-23-17-7(5-4-25-13(14)15-5)9(19)16-8-10(20)18-6(12(21)22)2-3-24-11(8)18/h2,4,8,11H,3H2,1H3,(H2,14,15)(H,16,19)(H,21,22)/p-1
# pred out: InChI=1S/C13H13N5O5S2/c1-23-17-7(5-4-25-13(14)15-5)9(19)16-8-10(20)18-6(12(21)22)2-3-24-11(8)18/h2,4,8,11H,3H2,1H3,(H2,14,15)(H,16,19)(H,21,22)/p-1/b17-7+
# COC(=O)C(NC(=O)C1=CC=C(I)C=C1NS(=O)(=O)C1=CC=CC2=NSN=C21)C(C1=CC=C(Cl)C=C1)C1=CC=C(Cl)C=C1
# pred in: InChI=1S/C29H21Cl2IN4O5S2/c1-41-29(38)27(25(16-5-9-18(30)10-6-16)17-7-11-19(31)12-8-17)33-28(37)21-14-13-20(32)15-23(21)36-43(39,40)24-4-2-3-22-26(24)35-42-34-22/h2-15,25,27,36H,1H3,(H,33,37)
# pred out: InChI=1S/C29H20Cl2I2N2O6S/c1-41-29(38)26(16-2-6-18(30)7-3-16)34-28(37)22-12-10-21(33)15-24(22)35-42(39,40)25-13-11-20(32)14-23(25)27(36)17-4-8-19(31)9-5-17/h2-15,26,35H,1H3,(H,34,37)
# COC1=C2C(=C(N)C(F)=C1NCCNC1=NC=CC=C1)C(=O)C(C#N)=CN2C1CC1
# pred in: InChI=1S/C21H21FN6O2/c1-30-21-18(27-9-8-26-14-4-2-3-7-25-14)16(22)17(24)15-19(21)28(13-5-6-13)11-12(10-23)20(15)29/h2-4,7,11,13,27H,5-6,8-9,24H2,1H3,(H,25,26)
# pred out: InChI=1S/C24H18FN7O3/c1-35-24-20-17(23(34)12(6-26)9-30(20)15-2-3-15)19(29)18(25)21(24)32-11-14(8-28)22(33)13(7-27)10-31(32)16-4-5-16/h9-11,15-16H,2-5,29H2,1H3
# COC(=O)C1=C(C(=O)O)C(F)=C(OC)C(F)=C1F
# pred in: InChI=1S/C10H7F3O5/c1-17-8-6(12)3(9(14)15)4(10(16)18-2)5(11)7(8)13/h1-2H3,(H,14,15)
# pred out: InChI=1S/C11H9F3O5/c1-17-9-7(13)5(11(16)19-3)4(10(15)18-2)6(12)8(9)14/h1-3H3
# CCOC(=O)C1=CC=C2C=C(C3=CC=C4C(=C3)C(O[Si](C)(C)C(C)(C)C)CCC4(C)C)C=CC2=C1
# pred in: InChI=1S/C31H40O3Si/c1-9-33-29(32)25-13-12-21-18-22(10-11-23(21)19-25)24-14-15-27-26(20-24)28(16-17-31(27,5)6)34-35(7,8)30(2,3)4/h10-15,18-20,28H,9,16-17H2,1-8H3
# pred out: InChI=1S/C28H32O3Si/c1-7-30-27(29)20-9-8-19-16-21(11-10-20)22-12-14-24-23(18-22)13-15-26(25(24)17-19)31-32(5,6)28(2,3)4/h8-18,26H,7H2,1-6H3
# C=C(C1=CC=CC(O[Si](C)(C)C(C)(C)C)=C1)C1=CC(C)=C(OC)C=C1
# pred in: InChI=1S/C22H30O2Si/c1-16-14-19(12-13-21(16)23-6)17(2)18-10-9-11-20(15-18)24-25(7,8)22(3,4)5/h9-15H,2H2,1,3-8H3
# pred out: InChI=1S/C22H30OSi/c1-16-12-13-20(14-17(16)2)18(3)19-10-9-11-21(15-19)23-24(7,8)22(4,5)6/h9-15H,3H2,1-2,4-8H3
# CN1C(N)=NC(C2=C[NH]C=C2)(C2=CC(O)=CC=C2)C1=O
# pred in: InChI=1S/C14H14N4O2/c1-18-12(20)14(17-13(18)15,10-5-6-16-8-10)9-3-2-4-11(19)7-9/h2-8,16,19H,1H3,(H2,15,17)
# pred out: InChI=1S/C12H13N5O/c1-17-10(18)12(16-11(17)13,8-2-4-14-6-8)9-3-5-15-7-9/h2-7,14-15H,1H3,(H2,13,16)
# C1=CSC(=[N+]2CCN(CC3=CC=CC=C3)CC2)S1
# pred in: InChI=1S/C14H17N2S2/c1-2-4-13(5-3-1)12-15-6-8-16(9-7-15)14-17-10-11-18-14/h1-5,10-11H,6-9,12H2/q+1
# pred out: InChI=1S/H2O/h1H2
# RDKit ERROR: [22:48:06] SMILES Parse Error: unclosed ring for input: 'C1CN(CCN1CC2=CC=CC=C2)C3=C4SC=CS4'
# CNC(=O)N(CCC(=O)OC)CC1CC2C3=CC=CC4=C3C(=C[NH]4)CC2N(C)C1
# pred in: InChI=1S/C22H30N4O3/c1-23-22(28)26(8-7-20(27)29-3)13-14-9-17-16-5-4-6-18-21(16)15(11-24-18)10-19(17)25(2)12-14/h4-6,11,14,17,19,24H,7-10,12-13H2,1-3H3,(H,23,28)
# pred out: InChI=1S/C21H29N5O2/c1-22-19(27)12-26(21(28)23-2)11-13-7-16-15-5-4-6-17-20(15)14(9-24-17)8-18(16)25(3)10-13/h4-6,9,13,16,18,24H,7-8,10-12H2,1-3H3,(H,22,27)(H,23,28)
# O=C1COC2=C(C=C(C(F)(F)F)C=N2)N1
# pred in: InChI=1S/C8H5F3N2O2/c9-8(10,11)4-1-5-7(12-2-4)15-3-6(14)13-5/h1-2H,3H2,(H,13,14)
# pred out: InChI=1S/C8H5F3N2O2/c9-8(10,11)4-1-5-7(12-2-4)13-6(14)3-15-5/h1-2H,3H2,(H,12,13,14)

# %% [markdown]
# # ACS

# %%
data = pd.read_csv('../data/molbank/real-acs-evaluation/test.csv')
pred = pd.read_csv('../output/indigo/swin_base_50_dynamic_aug_sgroup/prediction_valid_acs.csv')

# data = pd.read_csv('/data/rsg/chemistry/jiang_guo/chemai/literature-ie/image-omr/molbank/real-acs-evaluation/test.csv')
# data['smiles'] = [s.replace(' ', '') for s in data['smiles_mittok'].values]
# pred = pd.read_csv('/data/rsg/chemistry/jiang_guo/chemai/literature-ie/image-omr/molbank/real-acs-evaluation/prediction_test.csv')

# %%
# print(np.mean(data['smiles'].values == pred['smiles'].values))
print(np.mean(data['InChI'].values == pred['SMILES_InChI'].values))
# Out:
# 0.5576923076923077

# %%
import albumentations as A

transform = A.ToGray(p=1)

exact_match = (data['InChI'].values == pred['SMILES_InChI'].values)

BASE = '../'
# BASE = '../data/molbank/real-acs-evaluation/'

cnt = 0 
for i, row in data.iterrows():
    if not exact_match[i]:
        cnt += 1
        print(row['file_path'])
        print(row['SMILES'])
        pred_smiles = pred.loc[i,'SMILES']
        print('pred:', pred_smiles)
        image = cv2.imread(BASE + row['file_path'])
        plt.figure(figsize=(10,5))
        plt.subplot(1,2,1)
        plt.axis('off')
        plt.imshow(image)
#         plt.subplot(1,2,2)
#         plt.axis('off')
#         transformed = transform(image=image)['image']
#         plt.imshow(transformed)
        plt.show()
        mol = Chem.MolFromSmiles(pred_smiles)
        mol1 = Chem.MolFromSmiles(row['SMILES'])
        img = Draw.MolsToGridImage([mol,mol1], subImgSize=(300,300), molsPerRow=2, useSVG=True)
        display(SVG(img))
#     if cnt == 50:
#         break
# Out:
# data/molbank/real-acs-evaluation/images/2.png
# COC(C=C1)=CC=C1C#CC(C=CC=C2)=C2C3=C(C=O)N4C=CC=CC4=C3C(OCC)=O
# pred: COC1=CC=C(C#CC2=C(C3=C(C=O)N4C=CC=CC4=C3C(=O)O)C=CC=C2)C=C1
# data/molbank/real-acs-evaluation/images/8.png
# O=C(C(C=CC=C1)=C1C2=O)[C-]2C3=CC4=CC=CC=C4N=C3.[Na+]
# pred: C1=CC=C2C(=C1)C=C(C=N2)C3=C(C4=C(C3=O)C=CC=C4)[O-].[Na+].[Na+]
# data/molbank/real-acs-evaluation/images/9.png
# [Ar]C(O)C
# pred: CC(C)O
# data/molbank/real-acs-evaluation/images/10.png
# [Ar]C(NC1=C2C(C=CC=N2)=CC=C1)=O
# pred: O=C(NC1=C2N=CC=CC2=CC=C1)C1=NC=CC=C1
# data/molbank/real-acs-evaluation/images/11.png
# BrC1=CC=C(C)C=C1
# pred: BrC1=CC=C(I)C=C1
# data/molbank/real-acs-evaluation/images/12.png
# O=[N+](/C=C/C1=CC=CC=C1)[O-]
# pred: O=C(O)C=CC1=CC=CC=C1
# data/molbank/real-acs-evaluation/images/13.png
# CC(C=C1)=CC=C1S(C([N+]([O-])=O)C2=CC(Cl)=CC=C2)(=O)=O
# pred: CC1=CC=C(S(=O)(=O)C(NC(=O)OC(C)(C)C)C2=CC=CC(Cl)=C2)C=C1
# data/molbank/real-acs-evaluation/images/15.png
# C1(SSC2=CC=CC=C2)=CC=CC=C1
# pred: C1=CC=C(C=C1)SSC2=CC=CC=C2.[Fe+2]
# data/molbank/real-acs-evaluation/images/16.png
# O=C(C[C@@]1([H])[C@@]2(C)CC[C@]3([H])[C@]1(C)CCCC3(C)C)C4=C2C=C(OC)C(OC)=C4N
# pred: C[C@@]12CCC[C@@]([C@H]1CC[C@@]3([C@@H]2CC(=O)C4=C3C(=C(C(=C4)OC)OC)N)C)C.[Si]
# data/molbank/real-acs-evaluation/images/17.png
# ClC1=CC=CC=C1[N+]([O-])=O
# pred: C1=CC=C(C(=C1)Cl)C(=O)O
# data/molbank/real-acs-evaluation/images/18.png
# O=C/C=C/C1=CC=CC=C1
# pred: C1=CC=C(C=C1)/C=C/C(=O)O
# data/molbank/real-acs-evaluation/images/22.png
# CC1=CC(F)=CC(C)=C1
# pred: [Li]C1=CC(C)=CC(I)=C1
# data/molbank/real-acs-evaluation/images/23.png
# CN1C2=C(C=C(B3OC(C)(C)C(C)(C)O3)C=C2)C4=CC=CC=C41
# pred: CC1(C)OB(C2=CC3=C(C=C2)[N-]C2=C3C=CC=C2)OC1(C)C
# data/molbank/real-acs-evaluation/images/25.png
# CN(C(C1=C(C=CC=C2)C2=CC3=C1C=CC=C3)C4)C(N(C)C4=O)=O
# pred: CN1C(=O)NC(C2=C3C=CC=CC3=CC3=C2C=CC=C3)C(=O)N1
# data/molbank/real-acs-evaluation/images/30.png
# O=S(C1=CC=CC=C1)(C(F)(F)F)=NS(=O)(C(F)(F)F)=O
# pred: C1CCCS(=C(CC1)S(=O)(=O)OS(=O)(=O)O)(C2=CC=CC=C2)S(=O)(=O)O
# data/molbank/real-acs-evaluation/images/33.png
# [H]C(C1CCCO1)=O
# pred: CCC(=O)C1CCCO1
# data/molbank/real-acs-evaluation/images/34.png
# OC1=CC=C(C[C]=O)C=C1
# pred: O=C(O)CC1=CC=C(O)C=C1
# data/molbank/real-acs-evaluation/images/37.png
# O=CC(C=CC=C1)=C1/C(C2=CC=CC=C2)=C3COC4=C/3C=CC=C4
# pred: CC1=C(C(C2=CC=CC=C2)=C2COC3=C2C=CC=C3)C=CC=C1
# data/molbank/real-acs-evaluation/images/39.png
# C1(C=CC2=CC(C=CC=C3)=C3C=C2)CCCO1
# pred: C1C[C@H](OC1)/C=C/[C@@H]2CCCO2
# data/molbank/real-acs-evaluation/images/40.png
# O=CC1=CC=CC=C1
# pred: C1=CC=C(C=C1)CO
# data/molbank/real-acs-evaluation/images/42.png
# O=C(/C(C)=C1OC(C2=C/1C=CC=C2)=O)C3=CC=C(Br)C=C3
# pred: CC(C(=O)C1=CC=C(Br)C=C1)=C1OC(=O)C2=C1C=CC=C2
# data/molbank/real-acs-evaluation/images/43.png
# O=C(/C(C)=C1OC(C2=C\1C=CC=C2)=O)C3=CC=C(Br)C=C3
# pred: CC(C(=O)C1=CC=C(Br)C=C1)=C1OC(=O)C2=C1C=CC=C2
# data/molbank/real-acs-evaluation/images/44.png
# O=C(C1=C([H])C=CC=C1)NC2=CC=CC=C2N3C=CC=N3
# pred: NC1=C(C(=O)NC2=CC=CC=C2N2C=CC=N2)C=CC=C1
# data/molbank/real-acs-evaluation/images/45.png
# O=C(C1=C(NS(C)(=O)=O)C=CC=C1)NC2=CC=CC=C2N3C=CC=N3
# pred: O=C(NC1=CC=CC=C1N1C=CC=N1)C1=C(NS(=O)(=O)O)C=CC=C1
# data/molbank/real-acs-evaluation/images/46.png
# O=C(C1=C([H])C=CC=C1)NC2=CC=CC=C2N3C=CC=N3
# pred: NC1=C(C(=O)NC2=CC=CC=C2N2C=CC=N2)C=CC=C1
# data/molbank/real-acs-evaluation/images/47.png
# CN1N=NC(C2=CC=CC([N+]([O-])=O)=C2)=N1
# pred: CN1N=NC(C2=CC=CC(C#N)=C2)=N1
# data/molbank/real-acs-evaluation/images/55.png
# O=C(C1=CC=CC=C1)C2=CC=CC=C2
# pred: C1=CC=C(C=C1)C(=O)C2=CC=CC=C2.O
# data/molbank/real-acs-evaluation/images/59.png
# [H]C(C1=CC=CC=C1O)=O
# pred: CCC(=O)C1=C(O)C=CC=C1
# data/molbank/real-acs-evaluation/images/64.png
# O=C(OCC)C(C1=C2C=CC=C1)C=C3C2C(C=CC=C4)=C4N3CC5=CC=CC=C5
# pred: CCC(=O)C1C(C2=CC=CC=C2)=C2C(C3=CC=CC=C3)C3C4=CC=CC=C4N2CC3=C1C=CC=C1
# data/molbank/real-acs-evaluation/images/65.png
# C1(C2=CC(C=CC=C3)=C3O2)CCC(C4=CC(C=CC=C5)=C5O4)CC1
# pred: C1=C(N2CCN(C3=CC4=C(C=CC=C4)O3)CC2)OC2=C1C=CC=C2
# data/molbank/real-acs-evaluation/images/67.png
# BrC1=CSC([C@H]2[C@H]3[C@@](CCCC3)(OCC4)[C@@H]4CO2)=C1
# pred: C1C[C@@H]2[C@H]([C@H](OC1)COC2)C3=CC(=CS3)Br
# data/molbank/real-acs-evaluation/images/68.png
# CC1=CC=CC=C1
# pred: CC1=C(N)C=CC=C1
# data/molbank/real-acs-evaluation/images/70.png
# CC1=C(C2=CC=C([N+]([O-])=O)C=C2)C(C3=CC=CC=C3)=NO1
# pred: CC1=C(C(=NO1)C2=CC=CC=C2)C3=CC=C(C=C3)NC(=O)C.O.O.O
# data/molbank/real-acs-evaluation/images/71.png
# IC1=CC=C([N+]([O-])=O)C=C1
# pred: O=S(=O)(O)C1=CC=C(I)C=C1
# data/molbank/real-acs-evaluation/images/73.png
# COCC#CC1=CC=CC=C1
# pred: COCC#CC1=CC=CC=C1.C1=CC=C(C=C1)C#C
# data/molbank/real-acs-evaluation/images/74.png
# CC1=CC=C(C(C2C(CCCC2=O)=O)=O)C([N+]([O-])=O)=C1
# pred: CC1=CC(=C(C=C1)C(=O)C2C(=O)CCCC2=O)NC(=O)OC(C)(C)C
# data/molbank/real-acs-evaluation/images/77.png
# C[C@@H](C1=CC=CC=C1)N(CC2=CC=CC=C2)[C@H]([C@H](OCC3=CC=CC=C3)CC(C#CC#CC#C[CH])=O)CC4=CC=CC=C4
# pred: C[C@@H](C1=CC=CC=C1)N(CC2=CC=CC=C2)[C@H](CC3=CC=CC=C3)[C@@H](CC(=O)C)OCC4=CC=CC=C4
# data/molbank/real-acs-evaluation/images/81.png
# COC1=CC=C(/C=C/C=C/C(C)=O)C=C1
# pred: COC1=CC=C(C=CC=CC(C)=O)C=C1
# data/molbank/real-acs-evaluation/images/84.png
# O=CC1=C(O)C(O)=CC2=C1OC3=C2[C@]4(C)[C@](CC[C@H]3C)([H])C(C)(C)CCC4
# pred: C[C@@H]1CC[C@]2(CCC(C(=C2[C@]3(C1=C(C4=C3OC5=C4C=C(C(=C5C)O)O)C)(C)C)C)O)O
# data/molbank/real-acs-evaluation/images/88.png
# O=C(C(CCO)C(OCC)=O)C1=CC=CC=C1
# pred: CCOC(=O)C(CCO)C(=O)C1=CC=CC=C1.[Fe+2]
# data/molbank/real-acs-evaluation/images/92.png
# CC1=NC2=CC=C(C(F)(F)F)C=C2C(C3=CC=CC=C3)=C1C4=CC=CC=C4
# pred: [Li+].CC1=CC=C2C(=C1)C(=C(C(=N2)C)C3=CC=CC=C3)C4=CC=CC=C4
# data/molbank/real-acs-evaluation/images/94.png
# CC1=CC(C(F)(F)F)=CC(C(F)(F)F)=C1
# pred: FC(F)(F)C1=CC(C(F)(F)F)=CC(C(F)(F)F)=C1
# data/molbank/real-acs-evaluation/images/96.png
# CC1=CC2(CC3=C1C=CC=C3)C4=C(C=CC=C4)C5=CC=CC=C52
# pred: CC1=CC2(CC3=C(C=CC=C3)C3=C2C=CC=C3)CC2=C1C=CC=C2
# data/molbank/real-acs-evaluation/images/101.png
# O=C1C(SC2=CC=CC=C2)=CSC3=C1C=CC=C3
# pred: C1=CC=C2C(=C1)C(=O)C(=CO2)SC3=CC=CC=C3
# data/molbank/real-acs-evaluation/images/105.png
# O=S(C([N+]([O-])=O)C1=CC=CC(Br)=C1)(C2=CC=C(C)C=C2)=O
# pred: CC(C)(C)OC(=O)NC(C1=CC=CC(Br)=C1)S(=O)(=O)C1=CC=C(C)C=C1
# data/molbank/real-acs-evaluation/images/107.png
# O=C1CCSCC1
# pred: O=C1CCOCC1
